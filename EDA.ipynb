# %% [markdown]
# # imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import data_io
import os
import utils
from tqdm import tqdm

# %% [markdown]
# # load data

# %%
# FakeNewsNet Dataset
gossip_fake = data_io.load_csv(r'data/FakeNewsNet/gossipcop_fake.csv')
gossip_real = data_io.load_csv(r'data/FakeNewsNet/gossipcop_real.csv')
political_fake = data_io.load_csv(r'data/FakeNewsNet/politifact_fake.csv')
political_real = data_io.load_csv(r'data/FakeNewsNet/politifact_real.csv')
gossip_fake["label"] = 0
gossip_fake["category"] = "gossip"
gossip_real["label"] = 1
gossip_real["category"] = "gossip"
political_fake["label"] = 0
political_fake["category"] = "political"
political_real["label"] = 1
political_real["category"] = "political"
FakeNewsNet = pd.concat([gossip_fake, gossip_real, political_fake, political_real], ignore_index=True)

# %%
FakeNewsNet.describe()
# Out:
#               label
# count  23196.000000
# mean       0.751897
# std        0.431921
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
FakeNewsNet.isnull().sum()
# Out:
# id              0
# news_url      330
# title           0
# tweet_ids    1501
# label           0
# category        0
# dtype: int64

# %%
FakeNewsNet.head()
# Out:
#                      id                                           news_url  \
# 0  gossipcop-2493749932  www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 1  gossipcop-4580247171  hollywoodlife.com/2018/05/05/paris-jackson-car...
# 2   gossipcop-941805037  variety.com/2017/biz/news/tax-march-donald-tru...
# 3  gossipcop-2547891536  www.dailymail.co.uk/femail/article-3499192/Do-...
# 4  gossipcop-5476631226  variety.com/2018/film/news/list-2018-oscar-nom...
#
#                                                title  \
# 0  Did Miley Cyrus and Liam Hemsworth secretly ge...
# 1  Paris Jackson & Cara Delevingne Enjoy Night Ou...
# 2  Celebrities Join Tax March in Protest of Donal...
# 3  Cindy Crawford's daughter Kaia Gerber wears a ...
# 4      Full List of 2018 Oscar Nominations – Variety
#
#                                            tweet_ids  label category
# 0  284329075902926848\t284332744559968256\t284335...      0   gossip
# 1  992895508267130880\t992897935418503169\t992899...      0   gossip
# 2  853359353532829696\t853359576543920128\t853359...      0   gossip
# 3  988821905196158981\t988824206556172288\t988825...      0   gossip
# 4  955792793632432131\t955795063925301249\t955798...      0   gossip

# %%
# therealsampat Dataset
fake_news = data_io.load_csv(r'data/therealsampat/Fake.csv')
true_news = data_io.load_csv(r'data/therealsampat/True.csv')
fake_news["label"] = 0
true_news["label"] = 1
fake_true_dataset = pd.concat([fake_news, true_news], ignore_index=True)

# %%
fake_true_dataset.describe()
# Out:
#               label
# count  44898.000000
# mean       0.477015
# std        0.499477
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
fake_true_dataset.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
fake_true_dataset.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
fake_true_dataset["subject"].value_counts()
# Out:
# subject
# politicsNews       11272
# worldnews          10145
# News                9050
# politics            6841
# left-news           4459
# Government News     1570
# US_News              783
# Middle-east          778
# Name: count, dtype: int64

# %%
# fake_or_real_news Dataset
fake_or_real_news = data_io.load_csv(r'data/fake_or_real_news.csv')

# %%
fake_or_real_news.describe()
# Out:
#          Unnamed: 0
# count   6335.000000
# mean    5280.415627
# std     3038.503953
# min        2.000000
# 25%     2674.500000
# 50%     5271.000000
# 75%     7901.000000
# max    10557.000000

# %%
fake_or_real_news.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
fake_or_real_news["label"].value_counts()
# Out:
# label
# REAL    3171
# FAKE    3164
# Name: count, dtype: int64

# %%
fake_or_real_news.isnull().sum()
# Out:
# Unnamed: 0    0
# title         0
# text          0
# label         0
# dtype: int64

# %%
# news_articles Dataset
news_articles = data_io.load_csv(r'data/news_articles.csv')

# %%
news_articles.describe()
# Out:
#           hasImage
# count  2095.000000
# mean      0.777088
# std       0.416299
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
news_articles["label"].value_counts()
# Out:
# label
# Fake    1294
# Real     801
# Name: count, dtype: int64

# %%
news_articles.isnull().sum()
# Out:
# author                      0
# published                   0
# title                       0
# text                       46
# language                    1
# site_url                    1
# main_img_url                1
# type                        1
# label                       1
# title_without_stopwords     2
# text_without_stopwords     50
# hasImage                    1
# dtype: int64

# %%
news_articles.head()
# Out:
#                  author                      published  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                Fed Up  2016-11-01T05:22:00.000+02:00
# 4                Fed Up  2016-11-01T21:56:00.000+02:00
#
#                                                title  \
# 0  muslims busted they stole millions in govt ben...
# 1  re why did attorney general loretta lynch plea...
# 2  breaking weiner cooperating with fbi on hillar...
# 3  pin drop speech by father of daughter kidnappe...
# 4  fantastic trumps  point plan to reform healthc...
#
#                                                 text language  \
# 0  print they should pay all the back all the mon...  english
# 1  why did attorney general loretta lynch plead t...  english
# 2  red state  \nfox news sunday reported this mor...  english
# 3  email kayla mueller was a prisoner and torture...  english
# 4  email healthcare reform to make america great ...  english
#
#               site_url                                       main_img_url  \
# 0  100percentfedup.com  http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# 1  100percentfedup.com  http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# 2  100percentfedup.com  http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# 3  100percentfedup.com  http://100percentfedup.com/wp-content/uploads/...
# 4  100percentfedup.com  http://100percentfedup.com/wp-content/uploads/...
#
#    type label                            title_without_stopwords  \
# 0  bias  Real        muslims busted stole millions govt benefits
# 1  bias  Real         attorney general loretta lynch plead fifth
# 2  bias  Real  breaking weiner cooperating fbi hillary email ...
# 3  bias  Real  pin drop speech father daughter kidnapped kill...
# 4  bias  Real  fantastic trumps point plan reform healthcare ...
#
#                               text_without_stopwords  hasImage
# 0  print pay back money plus interest entire fami...       1.0
# 1  attorney general loretta lynch plead fifth bar...       1.0
# 2  red state fox news sunday reported morning ant...       1.0
# 3  email kayla mueller prisoner tortured isis cha...       1.0
# 4  email healthcare reform make america great sin...       1.0

# %%
news_articles["type"].value_counts()
# Out:
# type
# bs            601
# bias          436
# conspiracy    430
# hate          244
# satire        146
# state         121
# junksci       102
# fake           15
# Name: count, dtype: int64

# %%
news_articles["hasImage"].value_counts()
# Out:
# hasImage
# 1.0    1628
# 0.0     467
# Name: count, dtype: int64

# %%
# liar_data Dataset
test = data_io.load_liar_table(r'data/liar_data/test.tsv')
train = data_io.load_liar_table(r'data/liar_data/train.tsv')
valid = data_io.load_liar_table(r'data/liar_data/valid.tsv')
liar_data = pd.concat([test, train, valid])

# %%
liar_data.describe()
# Out:
#        barely_true_c       false_c   half_true_c  mostly_true_c  \
# count   12789.000000  12789.000000  12789.000000   12789.000000
# mean       11.583939     13.359059     17.185785      16.497850
# std        18.978037     24.140086     35.847678      36.165276
# min         0.000000      0.000000      0.000000       0.000000
# 25%         0.000000      0.000000      0.000000       0.000000
# 50%         2.000000      2.000000      3.000000       3.000000
# 75%        12.000000     15.000000     13.000000      12.000000
# max        70.000000    114.000000    160.000000     163.000000
#
#        pants_on_fire_c
# count     12789.000000
# mean          6.251388
# std          16.180777
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           5.000000
# max         105.000000

# %%
liar_data.head()
# Out:
#            id       label                                          statement  \
# 0  11972.json        true  Building a wall on the U.S.-Mexico border will...
# 1  11685.json       false  Wisconsin is on pace to double the number of l...
# 2  11096.json       false  Says John McCain has done nothing to help the ...
# 3   5209.json   half-true  Suzanne Bonamici supports a plan that will cut...
# 4   9524.json  pants-fire  When asked by a reporter whether hes at the ce...
#
#                                              subject  \
# 0                                        immigration
# 1                                               jobs
# 2                    military,veterans,voting-record
# 3  medicare,message-machine-2012,campaign-adverti...
# 4  campaign-finance,legal-issues,campaign-adverti...
#
#                             speaker                   job      state  \
# 0                        rick-perry              Governor      Texas
# 1                 katrina-shankland  State representative  Wisconsin
# 2                      donald-trump       President-Elect   New York
# 3                     rob-cornilles            consultant     Oregon
# 4  state-democratic-party-wisconsin                   NaN  Wisconsin
#
#         party  barely_true_c  false_c  half_true_c  mostly_true_c  \
# 0  republican           30.0     30.0         42.0           23.0
# 1    democrat            2.0      1.0          0.0            0.0
# 2  republican           63.0    114.0         51.0           37.0
# 3  republican            1.0      1.0          3.0            1.0
# 4    democrat            5.0      7.0          2.0            2.0
#
#    pants_on_fire_c                         venue
# 0             18.0               Radio interview
# 1              0.0             a news conference
# 2             61.0  comments on ABC's This Week.
# 3              1.0                  a radio show
# 4              7.0                   a web video

# %%
liar_data["label"].value_counts()
# Out:
# label
# half-true      2627
# false          2507
# mostly-true    2454
# barely-true    2103
# true           2053
# pants-fire     1047
# Name: count, dtype: int64

# %%
liar_data["binary_label"] = liar_data["label"].apply(lambda x: 1 if x in ["false", "pants-fire", "barely-true"] else 0)

# %%
liar_data["binary_label"].value_counts()
# Out:
# binary_label
# 0    7134
# 1    5657
# Name: count, dtype: int64

# %%
# Fake News Stories Dataset
Fake_News_Stories = data_io.load_xlsx('data/Fake News Stories.xlsx')
Fake_News_Stories["label"] = 0

# %%
Fake_News_Stories.head()
# Out:
#    Article Number                                     URL of article  \
# 0           375.0  http://www.redflagnews.com/headlines-2016/cdc-...
# 1           376.0  http://www.redflagnews.com/headlines-2016/-out...
# 2           377.0  http://www.redflagnews.com/headlines-2016/whit...
# 3           378.0  http://www.redflagnews.com/headlines-2016/obam...
# 4           379.0  http://www.redflagnews.com/headlines-2016/cali...
#
#   Fake or Satire?                           URL of rebutting article  label
# 0            Fake     http://www.snopes.com/cdc-forced-vaccinations/      0
# 1            Fake     http://www.snopes.com/white-house-logo-change/      0
# 2            Fake  http://www.snopes.com/obama-veterans-money-to-...      0
# 3            Fake  http://www.snopes.com/obama-veterans-money-to-...      0
# 4            Fake  http://www.snopes.com/california-to-jail-clima...      0

# %%
Fake_News_Stories.describe()
# Out:
#        Article Number
# count      492.000000
# mean       289.792683
# std        169.817410
# min          2.000000
# 25%        138.750000
# 50%        296.500000
# 75%        432.250000
# max        595.000000

# %%
Fake_News_Stories.columns
# Out:
# Index(['Article Number', 'URL of article', 'Fake or Satire?',
#        'URL of rebutting article'],
#       dtype='object')

# %%
Fake_News_Stories["Fake or Satire?"].value_counts()
# Out:
# Fake or Satire?
# Fake       291
# Satire     176
# Satire      25
# Name: count, dtype: int64

# %%
tar_path = "data/PHEMEpreprocessed4multitask.tar.gz"
extract_path = "data/PHEME_extracted"
# data_io.extract_tar_gz(tar_path, extract_path)

# %%
data_io.show_files_in_directory(extract_path)
# Out:
# Files in directory data/PHEME_extracted:
# data/PHEME_extracted\saved_data\.DS_Store
# data/PHEME_extracted\saved_data\._.DS_Store
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\charliehebdo\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\charliehebdo\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\charliehebdo\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\charliehebdo\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\charliehebdo\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\charliehebdo\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\charliehebdo\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\clinton-health\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\clinton-health\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\clinton-health\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\clinton-health\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\clinton-health\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\clinton-health\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\clinton-health\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ebola-essien\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ebola-essien\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ebola-essien\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ebola-essien\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ebola-essien\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ebola-essien\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ebola-essien\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ferguson\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ferguson\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ferguson\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ferguson\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ferguson\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ferguson\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ferguson\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\germanwings-crash\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\germanwings-crash\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\germanwings-crash\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\germanwings-crash\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\germanwings-crash\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\germanwings-crash\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\germanwings-crash\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\gurlitt\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\gurlitt\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\gurlitt\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\gurlitt\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\gurlitt\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\gurlitt\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\gurlitt\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\marinajoyce\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\marinajoyce\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\marinajoyce\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\marinajoyce\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\marinajoyce\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\marinajoyce\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\marinajoyce\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ottawashooting\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ottawashooting\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ottawashooting\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ottawashooting\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ottawashooting\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ottawashooting\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\ottawashooting\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\prince-toronto\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\prince-toronto\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\prince-toronto\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\prince-toronto\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\prince-toronto\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\prince-toronto\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\prince-toronto\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\putinmissing\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\putinmissing\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\putinmissing\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\putinmissing\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\putinmissing\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\putinmissing\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\putinmissing\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\sydneysiege\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\sydneysiege\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\sydneysiege\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\sydneysiege\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\sydneysiege\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\sydneysiege\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_detection\sydneysiege\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\.DS_Store
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\charliehebdo\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\charliehebdo\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\charliehebdo\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\charliehebdo\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\charliehebdo\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\charliehebdo\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\clinton-health\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\clinton-health\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\clinton-health\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\clinton-health\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\clinton-health\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\clinton-health\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ebola-essien\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ebola-essien\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ebola-essien\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ebola-essien\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ebola-essien\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ebola-essien\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ferguson\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ferguson\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ferguson\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ferguson\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ferguson\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ferguson\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\germanwings-crash\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\germanwings-crash\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\germanwings-crash\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\germanwings-crash\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\germanwings-crash\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\germanwings-crash\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\gurlitt\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\gurlitt\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\gurlitt\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\gurlitt\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\gurlitt\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\gurlitt\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\marinajoyce\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\marinajoyce\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\marinajoyce\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\marinajoyce\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\marinajoyce\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\marinajoyce\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ottawashooting\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ottawashooting\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ottawashooting\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ottawashooting\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ottawashooting\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\ottawashooting\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\prince-toronto\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\prince-toronto\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\prince-toronto\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\prince-toronto\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\prince-toronto\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\prince-toronto\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\putinmissing\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\putinmissing\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\putinmissing\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\putinmissing\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\putinmissing\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\putinmissing\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\sydneysiege\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\sydneysiege\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\sydneysiege\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\sydneysiege\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\sydneysiege\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL2_stance\sydneysiege\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\charliehebdo\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\charliehebdo\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\charliehebdo\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\charliehebdo\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\charliehebdo\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\charliehebdo\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\charliehebdo\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\clinton-health\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\clinton-health\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\clinton-health\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\clinton-health\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\clinton-health\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\clinton-health\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\clinton-health\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ebola-essien\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ebola-essien\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ebola-essien\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ebola-essien\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ebola-essien\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ebola-essien\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ebola-essien\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ferguson\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ferguson\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ferguson\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ferguson\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ferguson\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ferguson\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ferguson\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\germanwings-crash\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\germanwings-crash\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\germanwings-crash\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\germanwings-crash\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\germanwings-crash\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\germanwings-crash\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\germanwings-crash\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\gurlitt\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\gurlitt\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\gurlitt\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\gurlitt\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\gurlitt\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\gurlitt\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\gurlitt\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\marinajoyce\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\marinajoyce\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\marinajoyce\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\marinajoyce\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\marinajoyce\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\marinajoyce\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\marinajoyce\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ottawashooting\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ottawashooting\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ottawashooting\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ottawashooting\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ottawashooting\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ottawashooting\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\ottawashooting\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\prince-toronto\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\prince-toronto\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\prince-toronto\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\prince-toronto\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\prince-toronto\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\prince-toronto\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\prince-toronto\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\putinmissing\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\putinmissing\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\putinmissing\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\putinmissing\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\putinmissing\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\putinmissing\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\putinmissing\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\sydneysiege\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\sydneysiege\ids.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\sydneysiege\labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\sydneysiege\mask.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\sydneysiege\rnr_labels.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\sydneysiege\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_MTL3\sydneysiege\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\.DS_Store
# data/PHEME_extracted\saved_data\saved_data_RumEv\dev\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\dev\ids.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\dev\labels.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\dev\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\dev\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\test\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\test\ids.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\test\labels.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\test\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\test\tweet_ids.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\train\fold_stance_labels.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\train\ids.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\train\labels.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\train\train_array.npy
# data/PHEME_extracted\saved_data\saved_data_RumEv\train\tweet_ids.npy

# %%
base_path = 'data/PHEME_extracted/saved_data/saved_data_MTL2_detection'

event_folders = [
    'charliehebdo', 'clinton-health', 'ebola-essien', 'ferguson',
    'germanwings-crash', 'gurlitt', 'marinajoyce', 'ottawashooting',
    'prince-toronto', 'putinmissing', 'sydneysiege'
]

label_stats = {}

for event in event_folders:
    label_path = os.path.join(base_path, event, 'labels.npy')
    if os.path.exists(label_path):
        labels = np.load(label_path, allow_pickle=True)
        unique, counts = np.unique(labels, return_counts=True)
        label_stats[event] = dict(zip(unique, counts))

label_df = pd.DataFrame(label_stats).fillna(0).astype(int).T
label_df['total'] = label_df.sum(axis=1)

print(label_df)

print("\nTotal for all labels:")
print(label_df.sum())
# Out:
#                        0     1  total
# charliehebdo       65513  4774  70287
# clinton-health       646   323    969
# ebola-essien         324   162    486
# ferguson           39561  3792  43353
# germanwings-crash   7523  1633   9156
# gurlitt              386    76    462
# marinajoyce          274   137    411
# ottawashooting     20624  4369  24993
# prince-toronto      1091   538   1629
# putinmissing        1286   316   1602
# sydneysiege        38382  5628  44010
#
# Total for all labels:
# 0        175610
# 1         21748
# total    197358
# dtype: int64

# %%
# all_result Dataset
all_result = data_io.load_csv(r'data/all_results.csv')

# %%
all_result.describe()
# Out:
#                 qid    annotation  normalized_annotation     age_group  \
# count  38685.000000  56475.000000           56475.000000  54503.000000
# mean      23.933644      1.554405              -0.207844      2.414418
# std       14.359327      2.602265               0.671414      1.035094
# min        0.000000     -1.000000              -1.000000      1.000000
# 25%       11.000000     -1.000000              -1.000000      2.000000
# 50%       24.000000      0.000000               0.000000      2.000000
# 75%       36.000000      5.000000               0.000000      3.000000
# max       48.000000      8.000000               1.000000      4.000000
#
#               order     vid_order
# count  17790.000000  14825.000000
# mean       9.134907      3.000000
# std        5.696940      1.414261
# min        0.000000      1.000000
# 25%        4.000000      2.000000
# 50%        9.000000      3.000000
# 75%       14.000000      4.000000
# max       19.000000      5.000000

# %%
all_result.head()
# Out:
#    qid                                      vid_url  \
# 0  0.0  https://www.youtube.com/watch?v=9gCN7pIX3Es
# 1  0.0  https://www.youtube.com/watch?v=r7ZFMiXP1PM
# 2  0.0  https://www.youtube.com/watch?v=SMDkvJRHaNM
# 3  0.0  https://www.youtube.com/watch?v=T9eBroSQ6ug
# 4  0.0  https://www.youtube.com/watch?v=VPKVBOHS6Rs
#
#                                            vid_title  \
# 0                Rare video from ground zero on 9/11
# 1          9/11 Anniversary: Behind the 19 Hijackers
# 2  The Falling Man | Behind The Photo | 100 Photo...
# 3                               9/11: 15 years later
# 4  Cameraman Recalls How Events of 9/11 Unfolded ...
#
#                                           aria-label  annotation stance  \
# 0  Rare video from ground zero on 9/11 by 60 Minu...           0    NaN
# 1  9/11 Anniversary: Behind the 19 Hijackers by A...           0    NaN
# 2  The Falling Man | Behind The Photo | 100 Photo...           0    NaN
# 3  9/11: 15 years later by CBS Sunday Morning 2 y...           0    NaN
# 4  Cameraman Recalls How Events of 9/11 Unfolded ...           0    NaN
#
#    normalized_annotation  age_group  gender activity activity_type topic  \
# 0                      0        3.0  Female   Search  Demographics   all
# 1                      0        4.0  Female   Search  Demographics   all
# 2                      0        4.0  Female   Search  Demographics   all
# 3                      0        4.0  Female   Search  Demographics   all
# 4                      0        4.0  Female   Search  Demographics   all
#
#                    geolocation geo_temperature component_name  order  \
# 0  us-east1-b (South Carolina)             NaN  SearchResults    NaN
# 1  us-east1-b (South Carolina)             NaN  SearchResults    NaN
# 2  us-east1-b (South Carolina)             NaN  SearchResults    NaN
# 3  us-east1-b (South Carolina)             NaN  SearchResults    NaN
# 4  us-east1-b (South Carolina)             NaN  SearchResults    NaN
#
#    vid_order
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
all_result.columns
# Out:
# Index(['qid', 'vid_url', 'vid_title', 'aria-label', 'annotation', 'stance',
#        'normalized_annotation', 'age_group', 'gender', 'activity',
#        'activity_type', 'topic', 'geolocation', 'geo_temperature',
#        'component_name', 'order', 'vid_order'],
#       dtype='object')

# %%
all_result["normalized_annotation"].value_counts()
# Out:
# normalized_annotation
#  0    28577
# -1    19818
#  1     8080
# Name: count, dtype: int64

# %%
all_result["annotation"].value_counts()
# Out:
# annotation
# -1    18835
#  5    17721
#  0     9942
#  1     6952
#  4     1128
#  2      983
#  3      525
#  8      287
#  7      102
# Name: count, dtype: int64

# %%
all_result = all_result[all_result['normalized_annotation'] != 0] 
all_result['label'] = all_result['normalized_annotation'].map({-1: 1, 1: 0})
all_result["label"].value_counts()
# Out:
# label
# 1    19818
# 0     8080
# Name: count, dtype: int64

# %%
#  BuzzFead Facebook Dataset
BuzzFead_Facebook = data_io.load_csv(r'data/facebook-fact-check.csv')
BuzzFead_Facebook["label"] = 0

# %%
BuzzFead_Facebook.describe()
# Out:
#          account_id       post_id   share_count  reaction_count  \
# count  2.282000e+03  2.282000e+03  2.212000e+03     2280.000000
# mean   1.867111e+14  3.299586e+15  4.044816e+03     5364.284649
# std    1.393826e+14  3.808724e+15  2.983192e+04    19126.544561
# min    6.231759e+10  5.510967e+14  1.000000e+00        2.000000
# 25%    1.145179e+14  1.247441e+15  2.400000e+01      149.000000
# 50%    1.840966e+14  1.290536e+15  9.600000e+01      545.500000
# 75%    3.469371e+14  1.540752e+15  7.390000e+02     2416.750000
# max    4.401065e+14  1.015386e+16  1.088995e+06   456458.000000
#
#        comment_count   label
# count    2280.000000  2282.0
# mean      516.102193     0.0
# std      3569.355445     0.0
# min         0.000000     0.0
# 25%        37.000000     0.0
# 50%       131.500000     0.0
# 75%       390.250000     0.0
# max    159047.000000     0.0

# %%
BuzzFead_Facebook["label"].value_counts()
# Out:
# label
# 0    2282
# Name: count, dtype: int64

# %%
BuzzFead_Facebook.head()
# Out:
#         account_id           post_id    Category               Page  \
# 0  184096565021911  1035057923259100  mainstream  ABC News Politics
# 1  184096565021911  1035269309904628  mainstream  ABC News Politics
# 2  184096565021911  1035305953234297  mainstream  ABC News Politics
# 3  184096565021911  1035322636565962  mainstream  ABC News Politics
# 4  184096565021911  1035352946562931  mainstream  ABC News Politics
#
#                                             Post URL Date Published Post Type  \
# 0  https://www.facebook.com/ABCNewsPolitics/posts...     2016-09-19     video
# 1  https://www.facebook.com/ABCNewsPolitics/posts...     2016-09-19      link
# 2  https://www.facebook.com/ABCNewsPolitics/posts...     2016-09-19      link
# 3  https://www.facebook.com/ABCNewsPolitics/posts...     2016-09-19      link
# 4  https://www.facebook.com/ABCNewsPolitics/posts...     2016-09-19     video
#
#                Rating Debate  share_count  reaction_count  comment_count  \
# 0  no factual content    NaN          NaN           146.0           15.0
# 1         mostly true    NaN          1.0            33.0           34.0
# 2         mostly true    NaN         34.0            63.0           27.0
# 3         mostly true    NaN         35.0           170.0           86.0
# 4         mostly true    NaN        568.0          3188.0         2815.0
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
#  BanFakeNews Dataset
BanFakeNews_Authentic = data_io.load_csv(r'data/BanFakeNews/Authentic.csv')
BanFakeNews_FakeNews = data_io.load_csv(r'data/BanFakeNews/FakeNews.csv')
BanFakeNews_labeledAuthentic = data_io.load_csv(r'data/BanFakeNews/LabeledAuthentic.csv')
BanFakeNews_labeledFakeNews = data_io.load_csv(r'data/BanFakeNews/LabeledFake.csv')

# %%
BanFakeNews_Authentic.columns
# Out:
# Index(['articleID', 'domain', 'date', 'category', 'headline', 'content',
#        'label'],
#       dtype='object')

# %%
BanFakeNews_FakeNews.columns
# Out:
# Index(['articleID', 'domain', 'date', 'category', 'headline', 'content',
#        'label'],
#       dtype='object')

# %%
BanFakeNews_labeledAuthentic.columns
# Out:
# Index(['articleID', 'domain', 'date', 'category', 'source', 'relation',
#        'headline', 'content', 'label'],
#       dtype='object')

# %%
BanFakeNews_labeledFakeNews.columns
# Out:
# Index(['articleID', 'domain', 'date', 'category', 'source', 'relation',
#        'headline', 'content', 'label', 'F-type'],
#       dtype='object')

# %%
combined_df = pd.concat([
    BanFakeNews_Authentic,
    BanFakeNews_FakeNews,
    BanFakeNews_labeledAuthentic,
    BanFakeNews_labeledFakeNews
], sort=False, ignore_index=True)
combined_df.to_csv('data/BanFakeNews/banfakenews_merged_full.csv', index=False)

BanFakeNews = data_io.load_csv(r'data/BanFakeNews/banfakenews_merged_full.csv')

# %%
BanFakeNews.head()
# Out:
#    articleID          domain                 date   category  \
# 0          1  jagonews24.com  2018-09-19 17:48:18  Education
# 1          2  jagonews24.com  2018-09-19 17:48:19   National
# 2          3  jagonews24.com  2018-09-19 17:48:20   National
# 3          4  jagonews24.com  2018-09-19 17:48:21      Crime
# 4          5  jagonews24.com  2018-09-19 17:48:21   National
#
#                                             headline  \
# 0   হট্টগোল করায় বাকৃবিতে দুইজন বরখাস্ত, ৬ জনকে শোকজ
# 1    মালয়েশিয়ায় কর্মী পাঠানোর ব্যবস্থা নেয়ার সুপারিশ
# 2  প্রেমের প্রস্তাবে রাজি না হওয়ায় স্কুলছাত্রীকে ...
# 3  মেডিয়েশনই মামলাজট নিরসনের পথ : বিচারপতি আহমেদ ...
# 4         টকশোতে বক্তব্য দিতে গিয়ে জাপা নেতার মৃত্যু
#
#                                              content  label source relation  \
# 0  গত ১৭ সেপ্টেম্বর বাংলাদেশ কৃষি বিশ্ববিদ্যালয়ে ...    1.0    NaN      NaN
# 1  বাংলাদেশের বৃহৎ শ্রমবাজার মালয়েশিয়ায় আবার শ্রম...    1.0    NaN      NaN
# 2  নরসিংদীর মনোহরদীতে প্রেমের প্রস্তাবে রাজি না হ...    1.0    NaN      NaN
# 3  সুপ্রিম কোর্টের হাইকোর্ট বিভাগের বিচারপতি আহমে...    1.0    NaN      NaN
# 4  মাদারীপুর সদরের উপজেলার লেকেরপাড়ে একটি বেসরকার...    1.0    NaN      NaN
#
#   F-type
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
lang = utils.detect_lang("ইউটিলাইজ করার ব্যাপারে দু'ইউনিট বসবাস")
lang
# Out:
# 'bn'

# %%
utils.translate("ইউটিলাইজ করার ব্যাপারে দু'ইউনিট বসবাস",lang)
# Out:
# 'Two units about utilizing'

# %%
tqdm.pandas()

BanFakeNews['headline_lang'] = BanFakeNews['headline'].progress_apply(lambda x: utils.detect_lang(x) if pd.notnull(x) else None)
BanFakeNews['headline_lang'].value_counts()
# Out:
# 100%|██████████| 58478/58478 [00:53<00:00, 1097.40it/s]
# headline_lang
# bn    58469
# en        7
# it        1
# et        1
# Name: count, dtype: int64

# %%
tqdm.pandas()

BanFakeNews['headline_translated'] = BanFakeNews.progress_apply(
    lambda row: row['headline'] if row['headline_lang'] == 'en' else utils.translate(row['headline'], row['headline_lang']),
    axis=1
)
# Out:
#   0%|          | 7/58478 [00:10<24:38:31,  1.52s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 tqdm.pandas()
# ----> 3 BanFakeNews['headline_translated'] = BanFakeNews.progress_apply(
#       4     lambda row: row['headline'] if row['headline_lang'] == 'en' else utils.translate(row['headline'], row['headline_lang']),
#       5     axis=1
#       6 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tqdm\std.py:917, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     914 # Apply the provided function (in **kwargs)
#     915 # on the df using our wrapper (which provides bar updating)
#     916 try:
# --> 917     return getattr(df, df_function)(wrapper, **kwargs)
#     918 finally:
#     919     t.close()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)  10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tqdm\std.py:912, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     906 def wrapper(*args, **kwargs):
#     907     # update tbar correctly
#     908     # it seems `pandas apply` calls `func` twice
#     909     # on the first column/row to decide whether it can
#     910     # take a fast or slow code path; so stop when t.total==t.n
#     911     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 912     return func(*args, **kwargs)
#
# Cell In[15], line 4, in <lambda>(row)
#       1 tqdm.pandas()
#       3 BanFakeNews['headline_translated'] = BanFakeNews.progress_apply(
# ----> 4     lambda row: row['headline'] if row['headline_lang'] == 'en' else utils.translate(row['headline'], row['headline_lang']),
#       5     axis=1
#       6 )
#
# File c:\Users\shlomias\Desktop\fake_news_detection\utils.py:9, in translate(text, source_lang, target_lang)
#       7 def translate(text, source_lang='auto', target_lang='en'):
#       8     translator = GoogleTranslator(source=source_lang, target=target_lang)
# ----> 9     return translator.translate(text)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\deep_translator\google.py:67, in GoogleTranslator.translate(self, text, **kwargs)
#      64 if self.payload_key:
#      65     self._url_params[self.payload_key] = text
# ---> 67 response = requests.get(
#      68     self._base_url, params=self._url_params, proxies=self.proxies
#      69 )
#      70 if response.status_code == 429:
#      71     raise TooManyRequests()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\response.py:931, in HTTPResponse.stream(self, amt, decode_content)
#     915 """
#     916 A generator wrapper for the read() method. A call will block until
#     917 ``amt`` bytes have been read from the connection or until the
#    (...)    928     'content-encoding' header.
#     929 """
#     930 if self.chunked and self.supports_chunked_reads():
# --> 931     yield from self.read_chunked(amt, decode_content=decode_content)
#     932 else:
#     933     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\response.py:1071, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1068     return None
#    1070 while True:
# -> 1071     self._update_chunk_length()
#    1072     if self.chunk_left == 0:
#    1073         break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\response.py:999, in HTTPResponse._update_chunk_length(self)
#     997 if self.chunk_left is not None:
#     998     return None
# --> 999 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1000 line = line.split(b";", 1)[0]
#    1001 try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
tqdm.pandas()

BanFakeNews['content_lang'] = BanFakeNews['headline'].progress_apply(lambda x: utils.detect_lang(x) if pd.notnull(x) else None)
BanFakeNews['content_lang'].value_counts()
# Out:
# 100%|██████████| 58478/58478 [01:01<00:00, 944.97it/s]
# content_lang
# bn    58469
# en        7
# it        1
# et        1
# Name: count, dtype: int64

# %%
tqdm.pandas()

BanFakeNews['content_translated'] = BanFakeNews.progress_apply(
    lambda row: row['content'] if row['content_lang'] == 'en' else utils.translate(row['content'], row['content_lang']),
    axis=1
)

# %%
BanFakeNews.describe()
# Out:
#           articleID         label
# count  58478.000000  58478.000000
# mean   26178.306868      0.955573
# std    19379.622643      0.206044
# min        1.000000      0.000000
# 25%     7094.000000      1.000000
# 50%    24555.500000      1.000000
# 75%    43085.750000      1.000000
# max    61780.000000      1.000000

# %%
BanFakeNews.isnull().sum()
# Out:
# articleID        0
# domain           0
# date             0
# category         0
# headline         0
# content          0
# label            0
# source       49977
# relation     49977
# F-type       57179
# dtype: int64

# %%
BanFakeNews["label"].value_counts()
# Out:
# label
# 1.0    55880
# 0.0     2598
# Name: count, dtype: int64

# %%
FakeNewsBot = data_io.load_csv(r'data/FakeNewsBot.csv')

# %%
FakeNewsBot.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
FakeNewsBot["label"].value_counts()
# Out:
# label
# 1    10413
# 0    10387
# Name: count, dtype: int64

# %%
opensources_fake_news = data_io.load_csv("data/FakeNewsDataset/opensources_fake_news_cleaned.csv","polars")

# %%
opensources_fake_news.head()
# Out:
# shape: (5, 8)
# ┌─────────┬───────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┐
# │ id      ┆ type      ┆ domain     ┆ scraped_at ┆ url        ┆ authors    ┆ title      ┆ content   │
# │ ---     ┆ ---       ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │ i64     ┆ str       ┆ str        ┆ str        ┆ str        ┆ str        ┆ str        ┆ str       │
# ╞═════════╪═══════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╡
# │ 4059478 ┆ political ┆ dailycalle ┆ 2017-11-27 ┆ http://dai ┆ null       ┆ The top 6  ┆ To commem │
# │         ┆           ┆ r.com      ┆            ┆ lycaller.c ┆            ┆ bloggers   ┆ orate     │
# │         ┆           ┆            ┆            ┆ om/2010/03 ┆            ┆ &/or       ┆ this      │
# │         ┆           ┆            ┆            ┆ …          ┆            ┆ person…    ┆ week’s    │
# │         ┆           ┆            ┆            ┆            ┆            ┆            ┆ lau…      │
# │ 4059479 ┆ bias      ┆ lifenews.c ┆ 2017-11-27 ┆ https://co ┆ Greg Scott ┆ Iran Now   ┆ FAIR USE  │
# │         ┆           ┆ om         ┆            ┆ nsciouslif ┆            ┆ Blamed for ┆ NOTICE.   │
# │         ┆           ┆            ┆            ┆ enews.com/ ┆            ┆ 9/11       ┆ Many of   │
# │         ┆           ┆            ┆            ┆ …          ┆            ┆            ┆ the s…    │
# │ 4059480 ┆ political ┆ dailycalle ┆ 2017-11-27 ┆ http://dai ┆ Jeff       ┆ The Daily  ┆ New       │
# │         ┆           ┆ r.com      ┆            ┆ lycaller.c ┆ Winkler,   ┆ Caller     ┆ Hampshire │
# │         ┆           ┆            ┆            ┆ om/buzz/ma ┆ Jonathan   ┆            ┆ is the    │
# │         ┆           ┆            ┆            ┆ …          ┆ Strong,…   ┆            ┆ state     │
# │         ┆           ┆            ┆            ┆            ┆            ┆            ┆ wit…      │
# │ 4059482 ┆ fake      ┆ coed.com   ┆ 2017-11-27 ┆ https://co ┆ President, ┆ Abigail    ┆ Abigail   │
# │         ┆           ┆            ┆            ┆ ed.com/201 ┆ Executive  ┆ Ratchford  ┆ Ratchford │
# │         ┆           ┆            ┆            ┆ 4/08/29/ab ┆ Editor - … ┆ is Winning ┆ ‘s        │
# │         ┆           ┆            ┆            ┆ …          ┆            ┆ I…         ┆ Instagram │
# │         ┆           ┆            ┆            ┆            ┆            ┆            ┆ …         │
# │ 4059484 ┆ fake      ┆ coed.com   ┆ 2017-11-27 ┆ https://co ┆ null       ┆ How To:    ┆ Nothing   │
# │         ┆           ┆            ┆            ┆ ed.com/201 ┆            ┆ Have Sex   ┆ says “I   │
# │         ┆           ┆            ┆            ┆ 0/04/09/ho ┆            ┆ In A Car   ┆ love you” │
# │         ┆           ┆            ┆            ┆ …          ┆            ┆            ┆ like…     │
# └─────────┴───────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┘

# %%
opensources_fake_news['type'].value_counts().sort('count', descending=True)
# opensources_fake_news['type'].value_counts().write_csv("types_counts.csv")
# Out:
# shape: (12, 2)
# ┌────────────┬─────────┐
# │ type       ┆ count   │
# │ ---        ┆ ---     │
# │ str        ┆ u32     │
# ╞════════════╪═════════╡
# │ reliable   ┆ 1807323 │
# │ political  ┆ 968205  │
# │ bias       ┆ 769874  │
# │ fake       ┆ 762178  │
# │ conspiracy ┆ 494184  │
# │ …          ┆ …       │
# │ clickbait  ┆ 174176  │
# │ unreliable ┆ 104537  │
# │ satire     ┆ 84735   │
# │ junksci    ┆ 79099   │
# │ hate       ┆ 64763   │
# └────────────┴─────────┘

# %% [markdown]
# reliable,1807323
# unknown,230532
# hate,64763
# unreliable,104537
# satire,84735
# clickbait,174176
# junksci,79099
# bias,769874
# rumor,375963
# fake,762178
# conspiracy,494184
# political,968205

# %%
def label_verdict(t):
    if t in ["fake", "satire", "unreliable", "clickbait", "rumor", "conspiracy", "hate", "bias", "junksci"]:
        return "fake"
    elif t in ["reliable"]:
        return "real"
    else:
        return "irrelevant"

opensources_fake_news = opensources_fake_news.with_columns([
    opensources_fake_news["type"].map_elements(label_verdict).alias("verdict")
])

opensources_fake_news['verdict'].value_counts().sort('count', descending=True)
# Out:
# C:\Users\shlomias\AppData\Local\Temp\ipykernel_18280\2406979966.py:10: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   opensources_fake_news["type"].map_elements(label_verdict).alias("verdict")
# shape: (3, 2)
# ┌────────────┬─────────┐
# │ verdict    ┆ count   │
# │ ---        ┆ ---     │
# │ str        ┆ u32     │
# ╞════════════╪═════════╡
# │ fake       ┆ 2909509 │
# │ real       ┆ 1807323 │
# │ irrelevant ┆ 1198737 │
# └────────────┴─────────┘

# %%
opensources_fake_news.null_count()
# Out:
# shape: (1, 9)
# ┌─────┬──────┬────────┬────────────┬───┬─────────┬───────┬─────────┬─────────┐
# │ id  ┆ type ┆ domain ┆ scraped_at ┆ … ┆ authors ┆ title ┆ content ┆ verdict │
# │ --- ┆ ---  ┆ ---    ┆ ---        ┆   ┆ ---     ┆ ---   ┆ ---     ┆ ---     │
# │ u32 ┆ u32  ┆ u32    ┆ u32        ┆   ┆ u32     ┆ u32   ┆ u32     ┆ u32     │
# ╞═════╪══════╪════════╪════════════╪═══╪═════════╪═══════╪═════════╪═════════╡
# │ 0   ┆ 0    ┆ 0      ┆ 0          ┆ … ┆ 2279919 ┆ 1381  ┆ 0       ┆ 0       │
# └─────┴──────┴────────┴────────────┴───┴─────────┴───────┴─────────┴─────────┘
